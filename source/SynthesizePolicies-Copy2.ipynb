# %%
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
from scipy import stats
from lib.DataManager import *
from lib.PolicyStats import *
from lib.Gridworld import *
from lib.Mockworld import *
import os
import cma
from cma.constraints_handler import AugmentedLagrangian, PopulationEvaluator
from IPython import display
import pickle
import random

# %% [markdown]
# ***Set Params***

# %%
#---SET PARAMS---
USE_GRIDWORLD = False
USE_PDIS = True
USE_BOTH_PDIS_AND_IS = True # If True, we take policies that pass both tests
percent_increase = 0.1
num_policies = 20
es_path = "pickles/pdis_2.pkl"
gamma = 0.95
delta = 0.01 #1 - delta, confidence
random_seed = 3125832 #NOTE, this seed is for numpy operations. Since we load in CMA-ES from file its seed and state are embedded in the save and constant
sub_dir = "pdis_2\\"
title_offset = 81 # 1, 11, 21, so on

# seeds 508 (is_1.pkl), 1337 (is_0.pkl), 88885555 (pdis_1.pkl), 877496444 (pdis_0.pkl), 3125832 (pdis_2.pkl)
np.random.seed(random_seed) #this is to recreate the same policies

# %% [markdown]
# ***Setup Environment***

# %%
num_states = 18
if(USE_GRIDWORLD):
    print("Using Gridworld")
    num_states = 23
num_actions = 4

# %%
path = "data\data.csv"
if(USE_GRIDWORLD):
    path = "data\gridworld_data.csv"

histories = GetHistories(path, gamma)
# random.shuffle(histories)
# Out:
# line 0
# line 1000000
# line 2000000
# line 3000000
# line 4000000
# line 5000000
# line 6000000
# line 7000000
# line 8000000
# line 9000000
# line 10000000
# line 11000000
# line 12000000
# line 13000000
# line 14000000
# line 15000000
# line 16000000
# line 17000000
# line 18000000
# line 19000000
# line 20000000
# line 21000000
# line 22000000
# line 23000000
# line 24000000
# line 25000000
# line 26000000
# line 27000000
# line 28000000
# line 29000000
# line 30000000
# line 31000000
# line 32000000
# line 33000000
# line 34000000
# line 35000000
# line 36000000
# line 37000000
# line 38000000
# line 39000000
# line 40000000
# line 41000000
# line 42000000
# line 43000000
# line 44000000
# line 45000000
# line 46000000
# line 47000000
# line 48000000
# line 49000000
# line 50000000
# line 51000000
# line 52000000
# line 53000000
# line 54000000
# line 55000000
# line 56000000
# line 57000000
# line 58000000
# line 59000000
# line 60000000
# line 61000000
# line 62000000

# %%
train, test = SplitData(histories)
# Out:
# 800000
# 200000

# %%
avg_exploratory_J = GetAverageReturn(histories)
# Out:
# Average Baseline Return : 1.172600237817154

# %%
target_performance = GetTargetPerformance(USE_GRIDWORLD, avg_exploratory_J, percent_increase)
# Out:
# Target Performance : 1.556907

# %%
exploration_policy = GetPolicy(train, num_states, num_actions, 1000)
print(exploration_policy)
# Out:
# [[0.25  0.25  0.25  0.25 ]
#  [0.25  0.25  0.25  0.25 ]
#  [0.25  0.25  0.25  0.25 ]
#  [0.25  0.25  0.25  0.25 ]
#  [0.25  0.25  0.25  0.25 ]
#  [0.25  0.25  0.25  0.25 ]
#  [0.25  0.25  0.25  0.25 ]
#  [0.25  0.25  0.25  0.25 ]
#  [0.25  0.25  0.25  0.25 ]
#  [0.25  0.25  0.25  0.25 ]
#  [0.25  0.25  0.25  0.25 ]
#  [0.25  0.25  0.25  0.25 ]
#  [0.25  0.25  0.25  0.25 ]
#  [0.25  0.25  0.25  0.25 ]
#  [0.25  0.25  0.25  0.25 ]
#  [0.    0.    0.    0.   ]
#  [0.25  0.25  0.25  0.25 ]
#  [0.375 0.375 0.125 0.125]]

# %%
ISFunc = ImportanceSampling
OtherFunc = PDImportanceSampling
if(USE_PDIS):
    ISFunc = PDImportanceSampling
    OtherFunc = ImportanceSampling

# %%
es = pickle.load(open(es_path, "rb"))
print("ES_Convergence : " + str(sum(es.mean**2)))
print(es.opts["seed"])
# Out:
# ES_Convergence : 209.2525169235557
# 698993

# %%
def policy_softmax(policy):
    numerators = np.exp(policy)
    return (numerators.T / np.sum(numerators, axis=1)).T

# %%
avg_returns = 0
new_policy = None
theoretical_fails = 0
actual_fails = 0
i = 0
while i < num_policies:
    passed_theoretical = False
    try:
        print("~x~~x~~~x~~~~~x~~~~~x~~~x~~~~~x~~~~x~~")
        print(i)
        solution = es.ask(1)[0].reshape(num_states, num_actions)
        solution[15,:] = 1
        new_policy = policy_softmax(solution)
        ConfirmBounds(False, target_performance, train, test, exploration_policy, gamma, new_policy, ISFunc, delta)
        if (USE_BOTH_PDIS_AND_IS):
            ConfirmBounds(False, target_performance, train, test, exploration_policy, gamma, new_policy, OtherFunc, delta)
        passed_theoretical = True
        #policy passes theoretic check

        actual_J = -1
        if(USE_GRIDWORLD):
            actual_J = GetGridworldReturn(new_policy, gamma, 100000)
        else:
            actual_J = GetMockworldReturn(new_policy, gamma, 100000)

        print("TEST RUN " + str(actual_J))
        print(actual_J > target_performance)
#         ConfirmBounds(True, actual_J, train, test, exploration_policy, gamma, new_policy, ISFunc, delta)
#         if (USE_BOTH_PDIS_AND_IS):
#             ConfirmBounds(True, actual_J, train, test, exploration_policy, gamma, new_policy, OtherFunc, delta)
        #policy passes actual check
        path = "text_policies\\" + sub_dir + "policy" + str(i + title_offset) + ".txt"
        WriteSolutionToTxt(path, solution)
        loaded_solution = LoadSolutionFromTxt(path, num_states, num_actions)
        assert np.sum(loaded_solution - solution) == 0
        
        avg_returns += actual_J
        i += 1
    except:
        print("___F A I L___")
        if(passed_theoretical):
            actual_fails += 1
        else:
            theoretical_fails += 1

avg_returns /= num_policies
print("Number of Actual Fails : " + str(actual_fails))
print("Number of Theoretical Fails : " + str(theoretical_fails))
print("Average Return : " + str(avg_returns))
print("Target : " + str(target_performance))
print("Confidence : " + str(delta))
# Out:
# ~x~~x~~~x~~~~~x~~~~~x~~~x~~~~~x~~~~x~~
# 0
# Value: 1.556907
# Predicted Baseline: 2.8387373714048074
# Safety Baseline: 4.419443053159396
# ---distance of return from lower bounds ---
# Looseness Of Prediction : 1.2818303714048074
# Looseness Of Safety : 2.8625360531593964
# -------------------------------------------
# Value: 1.556907
# Predicted Baseline: 2.1900860385776495
# Safety Baseline: 3.984449642898166
# ---distance of return from lower bounds ---
# Looseness Of Prediction : 0.6331790385776495
# Looseness Of Safety : 2.4275426428981657
# -------------------------------------------
# TEST RUN 7.184499290267285
# True
# ~x~~x~~~x~~~~~x~~~~~x~~~x~~~~~x~~~~x~~
# 1
# Value: 1.556907
# Predicted Baseline: 3.4503054327606897
# Safety Baseline: 4.354757107220704
# ---distance of return from lower bounds ---
# Looseness Of Prediction : 1.8933984327606896
# Looseness Of Safety : 2.797850107220704
# -------------------------------------------
# Value: 1.556907
# Predicted Baseline: 2.8997086757702677
# Safety Baseline: 3.936333504425554
# ---distance of return from lower bounds ---
# Looseness Of Prediction : 1.3428016757702677
# Looseness Of Safety : 2.3794265044255543
# -------------------------------------------
# TEST RUN 6.945771470268591
# True
# ~x~~x~~~x~~~~~x~~~~~x~~~x~~~~~x~~~~x~~
# 2
# Value: 1.556907
# Predicted Baseline: 2.4221151595810415
# Safety Baseline: 3.8350500174179896
# ---distance of return from lower bounds ---
# Looseness Of Prediction : 0.8652081595810415
# Looseness Of Safety : 2.2781430174179897
# -------------------------------------------
# Value: 1.556907
# Predicted Baseline: 1.721811165141851
# Safety Baseline: 3.3380671510182447
# ---distance of return from lower bounds ---
# Looseness Of Prediction : 0.16490416514185102
# Looseness Of Safety : 1.7811601510182447
# -------------------------------------------
# TEST RUN 6.92426083028045
# True
# ~x~~x~~~x~~~~~x~~~~~x~~~x~~~~~x~~~~x~~
# 3
# Value: 1.556907
# Predicted Baseline: 3.3008527264995235
# Safety Baseline: 4.1077959264437105
# ---distance of return from lower bounds ---
# Looseness Of Prediction : 1.7439457264995235
# Looseness Of Safety : 2.5508889264437107
# -------------------------------------------
# Value: 1.556907
# Predicted Baseline: 2.7387939167308692
# Safety Baseline: 3.6795263284780297
# ---distance of return from lower bounds ---
# Looseness Of Prediction : 1.1818869167308692
# Looseness Of Safety : 2.12261932847803
# -------------------------------------------
# TEST RUN 6.8826122570671195
# True
# ~x~~x~~~x~~~~~x~~~~~x~~~x~~~~~x~~~~x~~
# 4
# Value: 1.556907
# Predicted Baseline: 2.296531177187207
# Safety Baseline: 4.059772396574051
# ---distance of return from lower bounds ---
# Looseness Of Prediction : 0.739624177187207
# Looseness Of Safety : 2.502865396574051
# -------------------------------------------
# Value: 1.556907
# Predicted Baseline: 1.5504808155789025
# Safety Baseline: 3.5626667176098885
# ---distance of return from lower bounds ---
# Looseness Of Prediction : -0.006426184421097547
# Looseness Of Safety : 2.0057597176098882
# ___F A I L___
# ~x~~x~~~x~~~~~x~~~~~x~~~x~~~~~x~~~~x~~
# 4
# Value: 1.556907
# Predicted Baseline: 3.693297585842405
# Safety Baseline: 4.362818801400908
# ---distance of return from lower bounds ---
# Looseness Of Prediction : 2.1363905858424053
# Looseness Of Safety : 2.8059118014009083
# -------------------------------------------
# Value: 1.556907
# Predicted Baseline: 3.1638528505039956
# Safety Baseline: 3.9227604593227445
# ---distance of return from lower bounds ---
# Looseness Of Prediction : 1.6069458505039955
# Looseness Of Safety : 2.3658534593227447
# -------------------------------------------
# TEST RUN 7.106312337834318
# True
# ~x~~x~~~x~~~~~x~~~~~x~~~x~~~~~x~~~~x~~
# 5
# Value: 1.556907
# Predicted Baseline: 4.375679445662642
# Safety Baseline: 5.069135011623777
# ---distance of return from lower bounds ---
# Looseness Of Prediction : 2.818772445662642
# Looseness Of Safety : 3.512228011623777
# -------------------------------------------
# Value: 1.556907
# Predicted Baseline: 3.961870279220573
# Safety Baseline: 4.740059714066795
# ---distance of return from lower bounds ---
# Looseness Of Prediction : 2.4049632792205733
# Looseness Of Safety : 3.183152714066795
# -------------------------------------------
# TEST RUN 7.18962646133736
# True
# ~x~~x~~~x~~~~~x~~~~~x~~~x~~~~~x~~~~x~~
# 6
# Value: 1.556907
# Predicted Baseline: 4.235490364542572
# Safety Baseline: 5.161031114458875
# ---distance of return from lower bounds ---
# Looseness Of Prediction : 2.678583364542572
# Looseness Of Safety : 3.604124114458875
# -------------------------------------------
# Value: 1.556907
# Predicted Baseline: 3.783422228174829
# Safety Baseline: 4.864599423628435
# ---distance of return from lower bounds ---
# Looseness Of Prediction : 2.2265152281748293
# Looseness Of Safety : 3.307692423628435
# -------------------------------------------
# TEST RUN 6.988627803498935
# True
# ~x~~x~~~x~~~~~x~~~~~x~~~x~~~~~x~~~~x~~
# 7
# Value: 1.556907
# Predicted Baseline: 1.6906405794188366
# Safety Baseline: 3.0393536294920724
# ---distance of return from lower bounds ---
# Looseness Of Prediction : 0.13373357941883657
# Looseness Of Safety : 1.4824466294920724
# -------------------------------------------
# Value: 1.556907
# Predicted Baseline: 0.8532053661801751
# Safety Baseline: 2.377626445000715
# ---distance of return from lower bounds ---
# Looseness Of Prediction : -0.703701633819825
# Looseness Of Safety : 0.8207194450007151
# ___F A I L___
# ~x~~x~~~x~~~~~x~~~~~x~~~x~~~~~x~~~~x~~
# 7
# Value: 1.556907
# Predicted Baseline: 4.1973014362647305
# Safety Baseline: 4.8346729096018235
# ---distance of return from lower bounds ---
# Looseness Of Prediction : 2.6403944362647307
# Looseness Of Safety : 3.2777659096018237
# -------------------------------------------
# Value: 1.556907
# Predicted Baseline: 3.7446820775390295
# Safety Baseline: 4.524029942539569
# ---distance of return from lower bounds ---
# Looseness Of Prediction : 2.1877750775390297
# Looseness Of Safety : 2.967122942539569
# -------------------------------------------
# TEST RUN 6.748938724006265
# True
# ~x~~x~~~x~~~~~x~~~~~x~~~x~~~~~x~~~~x~~
# 8
# Value: 1.556907
# Predicted Baseline: 1.8711371804719494
# Safety Baseline: 3.7605117580239296
# ---distance of return from lower bounds ---
# Looseness Of Prediction : 0.3142301804719494
# Looseness Of Safety : 2.2036047580239293
# -------------------------------------------
# Value: 1.556907
# Predicted Baseline: 0.817817436668717
# Safety Baseline: 3.230563096696125
# ---distance of return from lower bounds ---
# Looseness Of Prediction : -0.7390895633312831
# Looseness Of Safety : 1.673656096696125
# ___F A I L___
# ~x~~x~~~x~~~~~x~~~~~x~~~x~~~~~x~~~~x~~
# 8
# Value: 1.556907
# Predicted Baseline: 2.0742484187140473
# Safety Baseline: 3.6374160750116884
# ---distance of return from lower bounds ---
# Looseness Of Prediction : 0.5173414187140473
# Looseness Of Safety : 2.0805090750116886
# -------------------------------------------
# Value: 1.556907
# Predicted Baseline: 1.2777558791809387
# Safety Baseline: 3.0760374903547634
# ---distance of return from lower bounds ---
# Looseness Of Prediction : -0.27915112081906135
# Looseness Of Safety : 1.5191304903547633
# ___F A I L___
# ~x~~x~~~x~~~~~x~~~~~x~~~x~~~~~x~~~~x~~
# 8
# Value: 1.556907
# Predicted Baseline: 3.7641020828725993
# Safety Baseline: 4.658940499269832
# ---distance of return from lower bounds ---
# Looseness Of Prediction : 2.207195082872599
# Looseness Of Safety : 3.102033499269832
# -------------------------------------------
# Value: 1.556907
# Predicted Baseline: 3.28905576399847
# Safety Baseline: 4.336470303843532
# ---distance of return from lower bounds ---
# Looseness Of Prediction : 1.73214876399847
# Looseness Of Safety : 2.779563303843532
# -------------------------------------------
# TEST RUN 6.515729343453895
# True
# ~x~~x~~~x~~~~~x~~~~~x~~~x~~~~~x~~~~x~~
# 9
# Value: 1.556907
# Predicted Baseline: 2.54787561808502
# Safety Baseline: 3.548077828193327
# ---distance of return from lower bounds ---
# Looseness Of Prediction : 0.9909686180850199
# Looseness Of Safety : 1.991170828193327
# -------------------------------------------
# Value: 1.556907
# Predicted Baseline: 1.8032478622910721
# Safety Baseline: 3.0396480993784545
# ---distance of return from lower bounds ---
# Looseness Of Prediction : 0.2463408622910721
# Looseness Of Safety : 1.4827410993784544
# -------------------------------------------
# TEST RUN 6.5883647715363605
# True
# ~x~~x~~~x~~~~~x~~~~~x~~~x~~~~~x~~~~x~~
# 10
# Value: 1.556907
# Predicted Baseline: 2.739353580574913
# Safety Baseline: 3.519880996502205
# ---distance of return from lower bounds ---
# Looseness Of Prediction : 1.182446580574913
# Looseness Of Safety : 1.9629739965022048
# -------------------------------------------
# Value: 1.556907
# Predicted Baseline: 2.0452344409248004
# Safety Baseline: 2.9465602143271212
# ---distance of return from lower bounds ---
# Looseness Of Prediction : 0.4883274409248004
# Looseness Of Safety : 1.3896532143271212
# -------------------------------------------
# TEST RUN 7.202317042873851
# True
# ~x~~x~~~x~~~~~x~~~~~x~~~x~~~~~x~~~~x~~
# 11
# Value: 1.556907
# Predicted Baseline: 3.0929487542055414
# Safety Baseline: 4.159758005889575
# ---distance of return from lower bounds ---
# Looseness Of Prediction : 1.5360417542055413
# Looseness Of Safety : 2.6028510058895753
# -------------------------------------------
# Value: 1.556907
# Predicted Baseline: 2.4894591435754974
# Safety Baseline: 3.70231810742458
# ---distance of return from lower bounds ---
# Looseness Of Prediction : 0.9325521435754973
# Looseness Of Safety : 2.1454111074245796
# -------------------------------------------
# TEST RUN 7.231534022748539
# True
# ~x~~x~~~x~~~~~x~~~~~x~~~x~~~~~x~~~~x~~
# 12
# Value: 1.556907
# Predicted Baseline: 3.825214219029257
# Safety Baseline: 4.54858687403243
# ---distance of return from lower bounds ---
# Looseness Of Prediction : 2.268307219029257
# Looseness Of Safety : 2.99167987403243
# -------------------------------------------
# Value: 1.556907
# Predicted Baseline: 3.306148451717984
# Safety Baseline: 4.131098016143044
# ---distance of return from lower bounds ---
# Looseness Of Prediction : 1.7492414517179842
# Looseness Of Safety : 2.574191016143044
# -------------------------------------------
# TEST RUN 7.277231796738652
# True
# ~x~~x~~~x~~~~~x~~~~~x~~~x~~~~~x~~~~x~~
# 13
# Value: 1.556907
# Predicted Baseline: -9.41337972193074
# Safety Baseline: 3.35205355651573
# ---distance of return from lower bounds ---
# Looseness Of Prediction : -10.97028672193074
# Looseness Of Safety : 1.79514655651573
# ___F A I L___
# ~x~~x~~~x~~~~~x~~~~~x~~~x~~~~~x~~~~x~~
# 13
# Value: 1.556907
# Predicted Baseline: 3.404713113928536
# Safety Baseline: 3.7475589919602976
# ---distance of return from lower bounds ---
# Looseness Of Prediction : 1.847806113928536
# Looseness Of Safety : 2.190651991960298
# -------------------------------------------
# Value: 1.556907
# Predicted Baseline: 2.840300172101828
# Safety Baseline: 3.252145358995815
# ---distance of return from lower bounds ---
# Looseness Of Prediction : 1.283393172101828
# Looseness Of Safety : 1.6952383589958149
# -------------------------------------------
# TEST RUN 6.547660438004896
# True
# ~x~~x~~~x~~~~~x~~~~~x~~~x~~~~~x~~~~x~~
# 14
# Value: 1.556907
# Predicted Baseline: 3.368800077118636
# Safety Baseline: 4.034739989982469
# ---distance of return from lower bounds ---
# Looseness Of Prediction : 1.8118930771186361
# Looseness Of Safety : 2.4778329899824696
# -------------------------------------------
# Value: 1.556907
# Predicted Baseline: 2.8182647115962567
# Safety Baseline: 3.5721199570475757
# ---distance of return from lower bounds ---
# Looseness Of Prediction : 1.2613577115962566
# Looseness Of Safety : 2.0152129570475754
# -------------------------------------------
# TEST RUN 6.951000420364362
# True
# ~x~~x~~~x~~~~~x~~~~~x~~~x~~~~~x~~~~x~~
# 15
# Value: 1.556907
# Predicted Baseline: 0.41515331518558973
# Safety Baseline: 4.772768038156171
# ---distance of return from lower bounds ---
# Looseness Of Prediction : -1.1417536848144103
# Looseness Of Safety : 3.215861038156171
# ___F A I L___
# ~x~~x~~~x~~~~~x~~~~~x~~~x~~~~~x~~~~x~~
# 15
# Value: 1.556907
# Predicted Baseline: 2.0012438175691205
# Safety Baseline: 4.319974132013522
# ---distance of return from lower bounds ---
# Looseness Of Prediction : 0.44433681756912047
# Looseness Of Safety : 2.7630671320135223
# -------------------------------------------
# Value: 1.556907
# Predicted Baseline: 1.1647224289602507
# Safety Baseline: 4.007337252752608
# ---distance of return from lower bounds ---
# Looseness Of Prediction : -0.39218457103974935
# Looseness Of Safety : 2.450430252752608
# ___F A I L___
# ~x~~x~~~x~~~~~x~~~~~x~~~x~~~~~x~~~~x~~
# 15

# %%
greed_policy = np.argmax(new_policy,axis=1)

if(USE_GRIDWORLD):
    print(np.insert(greed_policy, [12,16],[-1,-1]).reshape((5,5)))
else:
    print(greed_policy[-2:])
    print(greed_policy[:-2].reshape(4,4))
