# %%
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
from scipy import stats
from lib.DataManager import *
from lib.PolicyStats import *
from lib.Gridworld import *
from lib.Mockworld import *
import os
import cma
from cma.constraints_handler import AugmentedLagrangian, PopulationEvaluator
from IPython import display
import pickle
import random

# %% [markdown]
# ***Set Params***

# %%
#---SET PARAMS---
USE_PDIS = False
policies_dir = "C:\\Users\\mfcli\\Documents\\School\\F20\\687\\rl-policy-improvement\\" #PATH TO POLCICIES DIR
percent_increase = 0.1
gamma = 0.95
delta = 0.01 #1 - delta, confidence
num_policies = 100

# %% [markdown]
# ***Setup Environment***

# %%
num_states = 18
num_actions = 4

# %%
path = "data\data.csv"
histories = GetHistories(path, gamma)
random.shuffle(histories)
# Out:
# line 0
# line 1000000
# line 2000000
# line 3000000
# line 4000000
# line 5000000
# line 6000000
# line 7000000
# line 8000000
# line 9000000
# line 10000000
# line 11000000
# line 12000000
# line 13000000
# line 14000000
# line 15000000
# line 16000000
# line 17000000
# line 18000000
# line 19000000
# line 20000000
# line 21000000
# line 22000000
# line 23000000
# line 24000000
# line 25000000
# line 26000000
# line 27000000
# line 28000000
# line 29000000
# line 30000000
# line 31000000
# line 32000000
# line 33000000
# line 34000000
# line 35000000
# line 36000000
# line 37000000
# line 38000000
# line 39000000
# line 40000000
# line 41000000
# line 42000000
# line 43000000
# line 44000000
# line 45000000
# line 46000000
# line 47000000
# line 48000000
# line 49000000
# line 50000000
# line 51000000
# line 52000000
# line 53000000
# line 54000000
# line 55000000
# line 56000000
# line 57000000
# line 58000000
# line 59000000
# line 60000000
# line 61000000
# line 62000000

# %%
# random.shuffle(histories)
print(histories[0]["return"])
train, test = SplitData(histories)
# Out:
# 1.14159869113351
# 800000
# 200000

# %%
avg_exploratory_J = GetAverageReturn(histories)
# Out:
# Average Baseline Return : 1.1726002378171196

# %%
target_performance = GetTargetPerformance(False, avg_exploratory_J, percent_increase)
# Out:
# Target Performance : 1.556907

# %%
exploration_policy = GetPolicy(train, num_states, num_actions, 1000)
print(exploration_policy)
# Out:
# [[0.25  0.25  0.25  0.25 ]
#  [0.25  0.25  0.25  0.25 ]
#  [0.25  0.25  0.25  0.25 ]
#  [0.25  0.25  0.25  0.25 ]
#  [0.25  0.25  0.25  0.25 ]
#  [0.25  0.25  0.25  0.25 ]
#  [0.25  0.25  0.25  0.25 ]
#  [0.25  0.25  0.25  0.25 ]
#  [0.25  0.25  0.25  0.25 ]
#  [0.25  0.25  0.25  0.25 ]
#  [0.25  0.25  0.25  0.25 ]
#  [0.25  0.25  0.25  0.25 ]
#  [0.25  0.25  0.25  0.25 ]
#  [0.25  0.25  0.25  0.25 ]
#  [0.25  0.25  0.25  0.25 ]
#  [0.    0.    0.    0.   ]
#  [0.25  0.25  0.25  0.25 ]
#  [0.375 0.375 0.125 0.125]]

# %%
ISFunc = ImportanceSampling
if(USE_PDIS):
    ISFunc = PDImportanceSampling

# %%
def policy_softmax(policy):
    numerators = np.exp(policy)
    return (numerators.T / np.sum(numerators, axis=1)).T

# %%
avg_returns = 0
new_policy = None
theoretical_fails = 0
actual_fails = 0
failure_log = {}
for i in range(num_policies):
    passed_theoretical = False
    
    print("~x~~x~~~x~~~~~x~~~~~x~~~x~~~~~x~~~~x~~")
    print(i)
    path = "policy" + str(i + 1) + ".txt"
    solution = LoadSolutionFromTxt(policies_dir + path, num_states, num_actions)

    new_policy = policy_softmax(solution)
    try:
        ConfirmBounds(False, target_performance, train, test, exploration_policy, gamma, new_policy, ISFunc, delta)
    except:
        print("____FAIL FAIL___")
        theoretical_fails += 1
        failure_log[i] = 1
            
    #policy passes theoretic check

    actual_J = -1
    actual_J = GetMockworldReturn(new_policy, gamma, 1000)

    if(actual_J < 6):
        print("LESS THAN 6???")
    if(actual_J < target_performance):
        print("CODE RED")
        print("____FAIL FAIL___")
        actual_fails += 1
        failure_log[i] = 1
    
#     try:
#         ConfirmBounds(True, actual_J, train, test, exploration_policy, gamma, new_policy, ISFunc, delta)
#     except:
#         print("____FAIL FAIL___")
#         actual_fails += 1
#         failure_log[i] = 1
    #policy passes actual check
    avg_returns += actual_J
    
    if (i % 10 == 0):
        print("Number of Actual Fails : " + str(actual_fails))
        print("Number of Theoretical Fails : " + str(theoretical_fails))
        print(failure_log)

avg_returns /= (num_policies - actual_fails)
print("Number of Actual Fails : " + str(actual_fails))
print("Number of Theoretical Fails : " + str(theoretical_fails))
print("Average Return : " + str(avg_returns))
print("Target : " + str(target_performance))
print("Confidence : " + str(delta))
# Out:
# ~x~~x~~~x~~~~~x~~~~~x~~~x~~~~~x~~~~x~~
# 0
# Value: 1.556907
# Predicted Baseline: 3.13051222014044
# Safety Baseline: 4.483777063079873
# ---distance of return from lower bounds ---
# Looseness Of Prediction : 1.57360522014044
# Looseness Of Safety : 2.926870063079873
# -------------------------------------------
# Number of Actual Fails : 0
# Number of Theoretical Fails : 0
# {}
# ~x~~x~~~x~~~~~x~~~~~x~~~x~~~~~x~~~~x~~
# 1
# Value: 1.556907
# Predicted Baseline: 2.8132711678285034
# Safety Baseline: 4.462501075003975
# ---distance of return from lower bounds ---
# Looseness Of Prediction : 1.2563641678285034
# Looseness Of Safety : 2.9055940750039753
# -------------------------------------------
# ~x~~x~~~x~~~~~x~~~~~x~~~x~~~~~x~~~~x~~
# 2
# Value: 1.556907
# Predicted Baseline: 2.731911920282214
# Safety Baseline: 4.179088563920169
# ---distance of return from lower bounds ---
# Looseness Of Prediction : 1.1750049202822141
# Looseness Of Safety : 2.6221815639201695
# -------------------------------------------
# ~x~~x~~~x~~~~~x~~~~~x~~~x~~~~~x~~~~x~~
# 3
# Value: 1.556907
# Predicted Baseline: 3.353336318770605
# Safety Baseline: 4.544856288291426
# ---distance of return from lower bounds ---
# Looseness Of Prediction : 1.796429318770605
# Looseness Of Safety : 2.987949288291426
# -------------------------------------------
# ~x~~x~~~x~~~~~x~~~~~x~~~x~~~~~x~~~~x~~
# 4
# Value: 1.556907
# Predicted Baseline: 3.18849669851158
# Safety Baseline: 4.491161155852577
# ---distance of return from lower bounds ---
# Looseness Of Prediction : 1.6315896985115799
# Looseness Of Safety : 2.934254155852577
# -------------------------------------------
# ~x~~x~~~x~~~~~x~~~~~x~~~x~~~~~x~~~~x~~
# 5
# Value: 1.556907
# Predicted Baseline: 2.3225160793800885
# Safety Baseline: 4.935030089396183
# ---distance of return from lower bounds ---
# Looseness Of Prediction : 0.7656090793800885
# Looseness Of Safety : 3.3781230893961833
# -------------------------------------------
# ~x~~x~~~x~~~~~x~~~~~x~~~x~~~~~x~~~~x~~
# 6
# Value: 1.556907
# Predicted Baseline: 3.3382226388950222
# Safety Baseline: 4.509572312293109
# ---distance of return from lower bounds ---
# Looseness Of Prediction : 1.7813156388950222
# Looseness Of Safety : 2.9526653122931092
# -------------------------------------------
# ~x~~x~~~x~~~~~x~~~~~x~~~x~~~~~x~~~~x~~
# 7
# Value: 1.556907
# Predicted Baseline: 2.9415014903843453
# Safety Baseline: 3.990250370752224
# ---distance of return from lower bounds ---
# Looseness Of Prediction : 1.3845944903843452
# Looseness Of Safety : 2.4333433707522243
# -------------------------------------------
# ~x~~x~~~x~~~~~x~~~~~x~~~x~~~~~x~~~~x~~
# 8
# Value: 1.556907
# Predicted Baseline: 1.7079833637088635
# Safety Baseline: 4.548020348230821
# ---distance of return from lower bounds ---
# Looseness Of Prediction : 0.15107636370886346
# Looseness Of Safety : 2.9911133482308214
# -------------------------------------------
# ~x~~x~~~x~~~~~x~~~~~x~~~x~~~~~x~~~~x~~
# 9
# Value: 1.556907
# Predicted Baseline: 3.4877281072639534
# Safety Baseline: 5.103847153939474
# ---distance of return from lower bounds ---
# Looseness Of Prediction : 1.9308211072639534
# Looseness Of Safety : 3.546940153939474
# -------------------------------------------
# ~x~~x~~~x~~~~~x~~~~~x~~~x~~~~~x~~~~x~~
# 10
# Value: 1.556907
# Predicted Baseline: 3.323865686660308
# Safety Baseline: 5.212467597495786
# ---distance of return from lower bounds ---
# Looseness Of Prediction : 1.7669586866603078
# Looseness Of Safety : 3.6555605974957865
# -------------------------------------------
# Number of Actual Fails : 0
# Number of Theoretical Fails : 0
# {}
# ~x~~x~~~x~~~~~x~~~~~x~~~x~~~~~x~~~~x~~
# 11
# Value: 1.556907
# Predicted Baseline: 3.432292299298083
# Safety Baseline: 4.597852800578131
# ---distance of return from lower bounds ---
# Looseness Of Prediction : 1.875385299298083
# Looseness Of Safety : 3.0409458005781316
# -------------------------------------------
# ~x~~x~~~x~~~~~x~~~~~x~~~x~~~~~x~~~~x~~
# 12
# Value: 1.556907
# Predicted Baseline: 1.7195446027213723
# Safety Baseline: 3.4868594051342368
# ---distance of return from lower bounds ---
# Looseness Of Prediction : 0.1626376027213723
# Looseness Of Safety : 1.9299524051342367
# -------------------------------------------
# ~x~~x~~~x~~~~~x~~~~~x~~~x~~~~~x~~~~x~~
# 13
# Value: 1.556907
# Predicted Baseline: 3.190036476960656
# Safety Baseline: 4.358457351801272
# ---distance of return from lower bounds ---
# Looseness Of Prediction : 1.633129476960656
# Looseness Of Safety : 2.8015503518012723
# -------------------------------------------
# ~x~~x~~~x~~~~~x~~~~~x~~~x~~~~~x~~~~x~~
# 14
# Value: 1.556907
# Predicted Baseline: 3.664059680027239
# Safety Baseline: 4.31820701508881
# ---distance of return from lower bounds ---
# Looseness Of Prediction : 2.107152680027239
# Looseness Of Safety : 2.7613000150888105
# -------------------------------------------
# ~x~~x~~~x~~~~~x~~~~~x~~~x~~~~~x~~~~x~~
# 15
# Value: 1.556907
# Predicted Baseline: 2.3235817407282306
# Safety Baseline: 3.7527995668837475
# ---distance of return from lower bounds ---
# Looseness Of Prediction : 0.7666747407282306
# Looseness Of Safety : 2.1958925668837477
# -------------------------------------------
# ~x~~x~~~x~~~~~x~~~~~x~~~x~~~~~x~~~~x~~
# 16
# Value: 1.556907
# Predicted Baseline: 2.136229191931288
# Safety Baseline: 4.1123303923393335
# ---distance of return from lower bounds ---
# Looseness Of Prediction : 0.5793221919312879
# Looseness Of Safety : 2.5554233923393337
# -------------------------------------------
# ~x~~x~~~x~~~~~x~~~~~x~~~x~~~~~x~~~~x~~
# 17
# Value: 1.556907
# Predicted Baseline: 2.1977460807459765
# Safety Baseline: 3.6615274371759288
# ---distance of return from lower bounds ---
# Looseness Of Prediction : 0.6408390807459765
# Looseness Of Safety : 2.104620437175929
# -------------------------------------------
# ~x~~x~~~x~~~~~x~~~~~x~~~x~~~~~x~~~~x~~
# 18
# Value: 1.556907
# Predicted Baseline: 2.2277451622165065
# Safety Baseline: 4.1625032744384995
# ---distance of return from lower bounds ---
# Looseness Of Prediction : 0.6708381622165065
# Looseness Of Safety : 2.6055962744384997
# -------------------------------------------
# ~x~~x~~~x~~~~~x~~~~~x~~~x~~~~~x~~~~x~~
# 19
# Value: 1.556907
# Predicted Baseline: 2.760617662056255
# Safety Baseline: 3.6068051019233276
# ---distance of return from lower bounds ---
# Looseness Of Prediction : 1.203710662056255
# Looseness Of Safety : 2.0498981019233273
# -------------------------------------------
# ~x~~x~~~x~~~~~x~~~~~x~~~x~~~~~x~~~~x~~
# 20
# Value: 1.556907
# Predicted Baseline: 3.7135174606253405
# Safety Baseline: 5.521686670943097
# ---distance of return from lower bounds ---
# Looseness Of Prediction : 2.1566104606253402
# Looseness Of Safety : 3.9647796709430976
# -------------------------------------------
# Number of Actual Fails : 0
# Number of Theoretical Fails : 0
# {}
# ~x~~x~~~x~~~~~x~~~~~x~~~x~~~~~x~~~~x~~
# 21
# Value: 1.556907
# Predicted Baseline: 3.0172534242803875
# Safety Baseline: 5.182973209609125
# ---distance of return from lower bounds ---
# Looseness Of Prediction : 1.4603464242803874
# Looseness Of Safety : 3.6260662096091254
# -------------------------------------------
# ~x~~x~~~x~~~~~x~~~~~x~~~x~~~~~x~~~~x~~
# 22
# Value: 1.556907
# Predicted Baseline: 3.295187940066468
# Safety Baseline: 5.193800838575282
# ---distance of return from lower bounds ---
# Looseness Of Prediction : 1.738280940066468
# Looseness Of Safety : 3.636893838575282
# -------------------------------------------
# ~x~~x~~~x~~~~~x~~~~~x~~~x~~~~~x~~~~x~~
# 23
# Value: 1.556907
# Predicted Baseline: 2.820137192409138
# Safety Baseline: 4.958336692553599
# ---distance of return from lower bounds ---
# Looseness Of Prediction : 1.2632301924091378
# Looseness Of Safety : 3.4014296925535996
# -------------------------------------------
# ~x~~x~~~x~~~~~x~~~~~x~~~x~~~~~x~~~~x~~
# 24
# Value: 1.556907
# Predicted Baseline: 2.919931203979151
# Safety Baseline: 5.34292025135553
# ---distance of return from lower bounds ---
# Looseness Of Prediction : 1.363024203979151
# Looseness Of Safety : 3.78601325135553
# -------------------------------------------
# ~x~~x~~~x~~~~~x~~~~~x~~~x~~~~~x~~~~x~~
# 25
# Value: 1.556907
# Predicted Baseline: 3.1919841610473285
# Safety Baseline: 4.696849181000401
# ---distance of return from lower bounds ---
# Looseness Of Prediction : 1.6350771610473285
# Looseness Of Safety : 3.139942181000401
# -------------------------------------------
# ~x~~x~~~x~~~~~x~~~~~x~~~x~~~~~x~~~~x~~
# 26
# Value: 1.556907
# Predicted Baseline: 2.8650466137126354
# Safety Baseline: 4.684659668844384
# ---distance of return from lower bounds ---
# Looseness Of Prediction : 1.3081396137126353
# Looseness Of Safety : 3.1277526688443844
# -------------------------------------------
# ~x~~x~~~x~~~~~x~~~~~x~~~x~~~~~x~~~~x~~
# 27
# Value: 1.556907
# Predicted Baseline: 3.2865179086863865
# Safety Baseline: 4.981218865967094
# ---distance of return from lower bounds ---
# Looseness Of Prediction : 1.7296109086863865
# Looseness Of Safety : 3.424311865967094
# -------------------------------------------
# ~x~~x~~~x~~~~~x~~~~~x~~~x~~~~~x~~~~x~~
# 28
# Value: 1.556907
# Predicted Baseline: 2.5334373653163413
# Safety Baseline: 5.35829981566004
# ---distance of return from lower bounds ---
# Looseness Of Prediction : 0.9765303653163413
# Looseness Of Safety : 3.80139281566004
# -------------------------------------------
# ~x~~x~~~x~~~~~x~~~~~x~~~x~~~~~x~~~~x~~
# 29
# Value: 1.556907
# Predicted Baseline: 1.4777866817331589
# Safety Baseline: 4.333421964704527
# ---distance of return from lower bounds ---
# Looseness Of Prediction : -0.07912031826684118
# Looseness Of Safety : 2.7765149647045275
# ____FAIL FAIL___
# ~x~~x~~~x~~~~~x~~~~~x~~~x~~~~~x~~~~x~~
# 30
# Value: 1.556907
# Predicted Baseline: 3.0956117769106037
# Safety Baseline: 4.263653855873299
# ---distance of return from lower bounds ---
# Looseness Of Prediction : 1.5387047769106037
# Looseness Of Safety : 2.706746855873299
# -------------------------------------------
# Number of Actual Fails : 0
# Number of Theoretical Fails : 1
# {29: 1}
# ~x~~x~~~x~~~~~x~~~~~x~~~x~~~~~x~~~~x~~
# 31
# Value: 1.556907
# Predicted Baseline: 2.1290494792419823
# Safety Baseline: 5.372862798110899
# ---distance of return from lower bounds ---
# Looseness Of Prediction : 0.5721424792419822
# Looseness Of Safety : 3.815955798110899
# -------------------------------------------
# ~x~~x~~~x~~~~~x~~~~~x~~~x~~~~~x~~~~x~~
# 32
# Value: 1.556907
# Predicted Baseline: 3.397802800890527
# Safety Baseline: 5.621055465638595
# ---distance of return from lower bounds ---
# Looseness Of Prediction : 1.8408958008905272
# Looseness Of Safety : 4.0641484656385956
# -------------------------------------------
# ~x~~x~~~x~~~~~x~~~~~x~~~x~~~~~x~~~~x~~
# 33
# Value: 1.556907
# Predicted Baseline: 3.481269237679951
# Safety Baseline: 5.567212798945949
# ---distance of return from lower bounds ---
# Looseness Of Prediction : 1.924362237679951
# Looseness Of Safety : 4.010305798945949
# -------------------------------------------
# ~x~~x~~~x~~~~~x~~~~~x~~~x~~~~~x~~~~x~~
# 34
# Value: 1.556907
# Predicted Baseline: 3.251793022977054
# Safety Baseline: 5.488380221400667
# ---distance of return from lower bounds ---
# Looseness Of Prediction : 1.6948860229770542
# Looseness Of Safety : 3.931473221400667
# -------------------------------------------
# ~x~~x~~~x~~~~~x~~~~~x~~~x~~~~~x~~~~x~~
# 35
# Value: 1.556907
# Predicted Baseline: 2.9982738184034057
# Safety Baseline: 4.8361523173414644
# ---distance of return from lower bounds ---
# Looseness Of Prediction : 1.4413668184034056
# Looseness Of Safety : 3.2792453173414646
# -------------------------------------------
# ~x~~x~~~x~~~~~x~~~~~x~~~x~~~~~x~~~~x~~
# 36
# Value: 1.556907
# Predicted Baseline: 3.245978545590087
# Safety Baseline: 5.348017147237937
# ---distance of return from lower bounds ---
# Looseness Of Prediction : 1.6890715455900869
# Looseness Of Safety : 3.791110147237937
# -------------------------------------------
# ~x~~x~~~x~~~~~x~~~~~x~~~x~~~~~x~~~~x~~
# 37
# Value: 1.556907
# Predicted Baseline: 2.412830801509971
# Safety Baseline: 5.029737404780289
# ---distance of return from lower bounds ---
# Looseness Of Prediction : 0.8559238015099708
# Looseness Of Safety : 3.4728304047802894
# -------------------------------------------
# ~x~~x~~~x~~~~~x~~~~~x~~~x~~~~~x~~~~x~~
# 38
# Value: 1.556907
# Predicted Baseline: 2.6165725459874376
# Safety Baseline: 4.61324738833051
# ---distance of return from lower bounds ---
# Looseness Of Prediction : 1.0596655459874376
# Looseness Of Safety : 3.0563403883305105
# -------------------------------------------
# ~x~~x~~~x~~~~~x~~~~~x~~~x~~~~~x~~~~x~~
# 39
# Value: 1.556907
# Predicted Baseline: 1.9113533586464602
# Safety Baseline: 5.082893426615925
# ---distance of return from lower bounds ---
# Looseness Of Prediction : 0.3544463586464601
# Looseness Of Safety : 3.5259864266159253
# -------------------------------------------
# ~x~~x~~~x~~~~~x~~~~~x~~~x~~~~~x~~~~x~~
# 40
# Value: 1.556907
# Predicted Baseline: 3.413078700593503
# Safety Baseline: 5.440564665905921
# ---distance of return from lower bounds ---
# Looseness Of Prediction : 1.8561717005935028
# Looseness Of Safety : 3.883657665905921
# -------------------------------------------
# Number of Actual Fails : 0
# Number of Theoretical Fails : 1
# {29: 1}
# ~x~~x~~~x~~~~~x~~~~~x~~~x~~~~~x~~~~x~~
# 41
# Value: 1.556907
# Predicted Baseline: 3.767231843361079
# Safety Baseline: 5.11162817125979
# ---distance of return from lower bounds ---
# Looseness Of Prediction : 2.2103248433610787
# Looseness Of Safety : 3.55472117125979
# -------------------------------------------
# ~x~~x~~~x~~~~~x~~~~~x~~~x~~~~~x~~~~x~~
# 42
# Value: 1.556907
# Predicted Baseline: 1.7487079728843558
# Safety Baseline: 4.464398630532579
# ---distance of return from lower bounds ---
# Looseness Of Prediction : 0.1918009728843557
# Looseness Of Safety : 2.9074916305325793
# -------------------------------------------
# ~x~~x~~~x~~~~~x~~~~~x~~~x~~~~~x~~~~x~~
# 43
# Value: 1.556907
# Predicted Baseline: 2.1859499547358796
# Safety Baseline: 3.9487153708020513
# ---distance of return from lower bounds ---
# Looseness Of Prediction : 0.6290429547358796
# Looseness Of Safety : 2.3918083708020514
# -------------------------------------------
# ~x~~x~~~x~~~~~x~~~~~x~~~x~~~~~x~~~~x~~
# 44
# Value: 1.556907
# Predicted Baseline: 3.9455125542016134
# Safety Baseline: 5.872078163331226
# ---distance of return from lower bounds ---
# Looseness Of Prediction : 2.3886055542016136
# Looseness Of Safety : 4.315171163331226
# -------------------------------------------
# ~x~~x~~~x~~~~~x~~~~~x~~~x~~~~~x~~~~x~~
# 45
# Value: 1.556907
# Predicted Baseline: 3.9909526108969997
# Safety Baseline: 5.44921706861528
# ---distance of return from lower bounds ---
# Looseness Of Prediction : 2.434045610897
# Looseness Of Safety : 3.89231006861528
# -------------------------------------------
# ~x~~x~~~x~~~~~x~~~~~x~~~x~~~~~x~~~~x~~
# 46
# Value: 1.556907
# Predicted Baseline: 3.335118714009422
# Safety Baseline: 5.633651547812729
# ---distance of return from lower bounds ---
# Looseness Of Prediction : 1.7782117140094218
# Looseness Of Safety : 4.076744547812729
# -------------------------------------------
# ~x~~x~~~x~~~~~x~~~~~x~~~x~~~~~x~~~~x~~
# 47
# Value: 1.556907
# Predicted Baseline: 3.0334387401681457
# Safety Baseline: 5.330755526713491
# ---distance of return from lower bounds ---
# Looseness Of Prediction : 1.4765317401681457
# Looseness Of Safety : 3.7738485267134916
# -------------------------------------------
# ~x~~x~~~x~~~~~x~~~~~x~~~x~~~~~x~~~~x~~
# 48
# Value: 1.556907
# Predicted Baseline: 2.8614201468556413
# Safety Baseline: 5.359402711335582
# ---distance of return from lower bounds ---
# Looseness Of Prediction : 1.3045131468556412
# Looseness Of Safety : 3.802495711335582
# -------------------------------------------
# ~x~~x~~~x~~~~~x~~~~~x~~~x~~~~~x~~~~x~~
# 49
# Value: 1.556907
# Predicted Baseline: 2.880284511967293
# Safety Baseline: 5.543193513316785
# ---distance of return from lower bounds ---
# Looseness Of Prediction : 1.323377511967293
# Looseness Of Safety : 3.9862865133167853
# -------------------------------------------
# ~x~~x~~~x~~~~~x~~~~~x~~~x~~~~~x~~~~x~~
# 50
# Value: 1.556907
# Predicted Baseline: 2.4154668534389856
# Safety Baseline: 4.161521924529591
# ---distance of return from lower bounds ---
# Looseness Of Prediction : 0.8585598534389856
# Looseness Of Safety : 2.6046149245295913
# -------------------------------------------
# Number of Actual Fails : 0
# Number of Theoretical Fails : 1
# {29: 1}
# ~x~~x~~~x~~~~~x~~~~~x~~~x~~~~~x~~~~x~~
# 51
# Value: 1.556907
# Predicted Baseline: 2.3450845565454195
# Safety Baseline: 4.75207865980436
# ---distance of return from lower bounds ---
# Looseness Of Prediction : 0.7881775565454194
# Looseness Of Safety : 3.19517165980436
# -------------------------------------------
# ~x~~x~~~x~~~~~x~~~~~x~~~x~~~~~x~~~~x~~
# 52
# Value: 1.556907
# Predicted Baseline: 2.930810764287137
# Safety Baseline: 4.939755809489089
# ---distance of return from lower bounds ---
# Looseness Of Prediction : 1.3739037642871368
# Looseness Of Safety : 3.382848809489089
# -------------------------------------------
# ~x~~x~~~x~~~~~x~~~~~x~~~x~~~~~x~~~~x~~
# 53
# Value: 1.556907
# Predicted Baseline: 3.46606308944608
# Safety Baseline: 5.306634339305491
# ---distance of return from lower bounds ---
# Looseness Of Prediction : 1.90915608944608
# Looseness Of Safety : 3.7497273393054913
# -------------------------------------------
# ~x~~x~~~x~~~~~x~~~~~x~~~x~~~~~x~~~~x~~
# 54
# Value: 1.556907
# Predicted Baseline: 2.7339720612317358
# Safety Baseline: 4.790916895383807
# ---distance of return from lower bounds ---
# Looseness Of Prediction : 1.1770650612317357
# Looseness Of Safety : 3.2340098953838075
# -------------------------------------------
# ~x~~x~~~x~~~~~x~~~~~x~~~x~~~~~x~~~~x~~
# 55
# Value: 1.556907
# Predicted Baseline: 3.4762654042710883
# Safety Baseline: 4.876236586439277
# ---distance of return from lower bounds ---
# Looseness Of Prediction : 1.9193584042710883
# Looseness Of Safety : 3.3193295864392773
# -------------------------------------------
# ~x~~x~~~x~~~~~x~~~~~x~~~x~~~~~x~~~~x~~
# 56
# Value: 1.556907
# Predicted Baseline: 3.7192991869672554
# Safety Baseline: 6.144190060073688
# ---distance of return from lower bounds ---
# Looseness Of Prediction : 2.1623921869672555
# Looseness Of Safety : 4.5872830600736885
# -------------------------------------------
# ~x~~x~~~x~~~~~x~~~~~x~~~x~~~~~x~~~~x~~
# 57
# Value: 1.556907
# Predicted Baseline: 3.5095395887860414
# Safety Baseline: 4.641119186617511
# ---distance of return from lower bounds ---
# Looseness Of Prediction : 1.9526325887860414
# Looseness Of Safety : 3.0842121866175116
# -------------------------------------------
# ~x~~x~~~x~~~~~x~~~~~x~~~x~~~~~x~~~~x~~
# 58
# Value: 1.556907
# Predicted Baseline: 3.446820003980265
# Safety Baseline: 5.079827083461969
# ---distance of return from lower bounds ---
# Looseness Of Prediction : 1.8899130039802647
# Looseness Of Safety : 3.522920083461969
# -------------------------------------------
# ~x~~x~~~x~~~~~x~~~~~x~~~x~~~~~x~~~~x~~
# 59
# Value: 1.556907
# Predicted Baseline: 3.5556264173910863
# Safety Baseline: 4.763530455665194
# ---distance of return from lower bounds ---
# Looseness Of Prediction : 1.9987194173910863
# Looseness Of Safety : 3.206623455665194
# -------------------------------------------
# ~x~~x~~~x~~~~~x~~~~~x~~~x~~~~~x~~~~x~~
# 60
# Value: 1.556907
# Predicted Baseline: 3.1485564933567867
# Safety Baseline: 5.2802000270682115
# ---distance of return from lower bounds ---
# Looseness Of Prediction : 1.5916494933567866
# Looseness Of Safety : 3.7232930270682116
# -------------------------------------------
# Number of Actual Fails : 0
# Number of Theoretical Fails : 1
# {29: 1}
# ~x~~x~~~x~~~~~x~~~~~x~~~x~~~~~x~~~~x~~
# 61
# Value: 1.556907
# Predicted Baseline: 1.4399169215075904
# Safety Baseline: 4.62047411618253
# ---distance of return from lower bounds ---
# Looseness Of Prediction : -0.11699007849240961
# Looseness Of Safety : 3.06356711618253
# ____FAIL FAIL___
# ~x~~x~~~x~~~~~x~~~~~x~~~x~~~~~x~~~~x~~
# 62
# Value: 1.556907
# Predicted Baseline: 0.8908657040840717
# Safety Baseline: 3.7303179922650394
# ---distance of return from lower bounds ---
# Looseness Of Prediction : -0.6660412959159283
# Looseness Of Safety : 2.1734109922650395
# ____FAIL FAIL___
# ~x~~x~~~x~~~~~x~~~~~x~~~x~~~~~x~~~~x~~
# 63
# Value: 1.556907
# Predicted Baseline: 1.55149384769918
# Safety Baseline: 3.5507692982854078
# ---distance of return from lower bounds ---
# Looseness Of Prediction : -0.005413152300820068
# Looseness Of Safety : 1.9938622982854077
# ____FAIL FAIL___
# ~x~~x~~~x~~~~~x~~~~~x~~~x~~~~~x~~~~x~~
# 64
# Value: 1.556907
# Predicted Baseline: 2.363358101108804
# Safety Baseline: 4.9617334730559195
# ---distance of return from lower bounds ---
# Looseness Of Prediction : 0.8064511011088038
# Looseness Of Safety : 3.4048264730559197
# -------------------------------------------
# ~x~~x~~~x~~~~~x~~~~~x~~~x~~~~~x~~~~x~~
# 65
# Value: 1.556907
# Predicted Baseline: 1.026365278447555
# Safety Baseline: 5.357748371626325
# ---distance of return from lower bounds ---
# Looseness Of Prediction : -0.5305417215524451
# Looseness Of Safety : 3.8008413716263254
# ____FAIL FAIL___
# ~x~~x~~~x~~~~~x~~~~~x~~~x~~~~~x~~~~x~~
# 66
# Value: 1.556907
# Predicted Baseline: 2.2329104462644054
# Safety Baseline: 5.052296493104363
# ---distance of return from lower bounds ---
# Looseness Of Prediction : 0.6760034462644053
# Looseness Of Safety : 3.495389493104363
# -------------------------------------------
# ~x~~x~~~x~~~~~x~~~~~x~~~x~~~~~x~~~~x~~
# 67
# Value: 1.556907
# Predicted Baseline: 2.6743579666479347
# Safety Baseline: 4.841688489330998
# ---distance of return from lower bounds ---
# Looseness Of Prediction : 1.1174509666479346
# Looseness Of Safety : 3.2847814893309986
# -------------------------------------------
# ~x~~x~~~x~~~~~x~~~~~x~~~x~~~~~x~~~~x~~
# 68
# Value: 1.556907
# Predicted Baseline: 1.687326723858761
# Safety Baseline: 5.080630685736894
# ---distance of return from lower bounds ---
# Looseness Of Prediction : 0.130419723858761
# Looseness Of Safety : 3.5237236857368943
# -------------------------------------------
# ~x~~x~~~x~~~~~x~~~~~x~~~x~~~~~x~~~~x~~
# 69
# Value: 1.556907
# Predicted Baseline: 2.8757945134426475
# Safety Baseline: 4.854394725636391
# ---distance of return from lower bounds ---
# Looseness Of Prediction : 1.3188875134426474
# Looseness Of Safety : 3.2974877256363913
# -------------------------------------------
# ~x~~x~~~x~~~~~x~~~~~x~~~x~~~~~x~~~~x~~
# 70
# Value: 1.556907
# Predicted Baseline: 2.8948468459854215
# Safety Baseline: 5.821579358766587
# ---distance of return from lower bounds ---
# Looseness Of Prediction : 1.3379398459854215
# Looseness Of Safety : 4.264672358766587
# -------------------------------------------
# Number of Actual Fails : 0
# Number of Theoretical Fails : 5
# {29: 1, 61: 1, 62: 1, 63: 1, 65: 1}
# ~x~~x~~~x~~~~~x~~~~~x~~~x~~~~~x~~~~x~~
# 71
# Value: 1.556907
# Predicted Baseline: 3.5087988576614784
# Safety Baseline: 5.606480674426796
# ---distance of return from lower bounds ---
# Looseness Of Prediction : 1.9518918576614783
# Looseness Of Safety : 4.049573674426796
# -------------------------------------------
# ~x~~x~~~x~~~~~x~~~~~x~~~x~~~~~x~~~~x~~
# 72
# Value: 1.556907
# Predicted Baseline: 1.9821858603445035
# Safety Baseline: 4.783194657420722
# ---distance of return from lower bounds ---
# Looseness Of Prediction : 0.42527886034450346
# Looseness Of Safety : 3.2262876574207224
# -------------------------------------------
# ~x~~x~~~x~~~~~x~~~~~x~~~x~~~~~x~~~~x~~
# 73
# Value: 1.556907
# Predicted Baseline: 2.4254186933567716
# Safety Baseline: 5.226959799520163
# ---distance of return from lower bounds ---
# Looseness Of Prediction : 0.8685116933567716
# Looseness Of Safety : 3.670052799520163
# -------------------------------------------
# ~x~~x~~~x~~~~~x~~~~~x~~~x~~~~~x~~~~x~~
# 74
# Value: 1.556907
# Predicted Baseline: 2.453122087637305
# Safety Baseline: 5.101008047358039
# ---distance of return from lower bounds ---
# Looseness Of Prediction : 0.896215087637305
# Looseness Of Safety : 3.5441010473580388
# -------------------------------------------
# ~x~~x~~~x~~~~~x~~~~~x~~~x~~~~~x~~~~x~~
# 75
# Value: 1.556907
# Predicted Baseline: 3.6238367181674995
# Safety Baseline: 5.308610239874706
# ---distance of return from lower bounds ---
# Looseness Of Prediction : 2.0669297181674997
# Looseness Of Safety : 3.751703239874706
# -------------------------------------------
# ~x~~x~~~x~~~~~x~~~~~x~~~x~~~~~x~~~~x~~
# 76
# Value: 1.556907
# Predicted Baseline: 1.2501083064784
# Safety Baseline: 5.925515912720511
# ---distance of return from lower bounds ---
# Looseness Of Prediction : -0.30679869352160005
# Looseness Of Safety : 4.368608912720511
# ____FAIL FAIL___
# ~x~~x~~~x~~~~~x~~~~~x~~~x~~~~~x~~~~x~~
# 77
# Value: 1.556907
# Predicted Baseline: 1.8533674855330862
# Safety Baseline: 4.027817594794115
# ---distance of return from lower bounds ---
# Looseness Of Prediction : 0.2964604855330861
# Looseness Of Safety : 2.4709105947941152
# -------------------------------------------
# ~x~~x~~~x~~~~~x~~~~~x~~~x~~~~~x~~~~x~~
# 78
# Value: 1.556907
# Predicted Baseline: 2.3970990072890617
# Safety Baseline: 6.401911481458679
# ---distance of return from lower bounds ---
# Looseness Of Prediction : 0.8401920072890616
# Looseness Of Safety : 4.8450044814586795
# -------------------------------------------
# ~x~~x~~~x~~~~~x~~~~~x~~~x~~~~~x~~~~x~~
# 79
# Value: 1.556907
# Predicted Baseline: 2.349729118037743
# Safety Baseline: 5.912496329195147
# ---distance of return from lower bounds ---
# Looseness Of Prediction : 0.792822118037743
# Looseness Of Safety : 4.355589329195147
# -------------------------------------------
# ~x~~x~~~x~~~~~x~~~~~x~~~x~~~~~x~~~~x~~
# 80
# Value: 1.556907
# Predicted Baseline: 2.1584261585364155
# Safety Baseline: 3.63037629739294
# ---distance of return from lower bounds ---
# Looseness Of Prediction : 0.6015191585364155
# Looseness Of Safety : 2.07346929739294
# -------------------------------------------
# Number of Actual Fails : 0
# Number of Theoretical Fails : 6
# {29: 1, 61: 1, 62: 1, 63: 1, 65: 1, 76: 1}
# ~x~~x~~~x~~~~~x~~~~~x~~~x~~~~~x~~~~x~~
# 81
# Value: 1.556907
# Predicted Baseline: 2.726212051915506
# Safety Baseline: 5.035747335606636
# ---distance of return from lower bounds ---
# Looseness Of Prediction : 1.169305051915506
# Looseness Of Safety : 3.4788403356066357
# -------------------------------------------
# ~x~~x~~~x~~~~~x~~~~~x~~~x~~~~~x~~~~x~~
# 82
# Value: 1.556907
# Predicted Baseline: 1.7721353519656455
# Safety Baseline: 4.918364970079724
# ---distance of return from lower bounds ---
# Looseness Of Prediction : 0.2152283519656455
# Looseness Of Safety : 3.361457970079724
# -------------------------------------------
# ~x~~x~~~x~~~~~x~~~~~x~~~x~~~~~x~~~~x~~
# 83
# Value: 1.556907
# Predicted Baseline: 2.479583268455748
# Safety Baseline: 5.579345078772468
# ---distance of return from lower bounds ---
# Looseness Of Prediction : 0.9226762684557481
# Looseness Of Safety : 4.022438078772468
# -------------------------------------------
# ~x~~x~~~x~~~~~x~~~~~x~~~x~~~~~x~~~~x~~
# 84
# Value: 1.556907
# Predicted Baseline: 3.049281406431998
# Safety Baseline: 6.138290672325427
# ---distance of return from lower bounds ---
# Looseness Of Prediction : 1.492374406431998
# Looseness Of Safety : 4.581383672325427
# -------------------------------------------
# ~x~~x~~~x~~~~~x~~~~~x~~~x~~~~~x~~~~x~~
# 85
