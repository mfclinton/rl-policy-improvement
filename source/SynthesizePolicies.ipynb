# %%
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
from scipy import stats
from lib.DataManager import *
from lib.PolicyStats import *
from lib.Gridworld import *
from lib.Mockworld import *
import os
import cma
from cma.constraints_handler import AugmentedLagrangian, PopulationEvaluator
from IPython import display
import pickle
import random

# %% [markdown]
# ***Set Params***

# %%
#---SET PARAMS---
USE_GRIDWORLD = False
USE_PDIS = True
USE_BOTH_PDIS_AND_IS = True # If True, we take policies that pass both tests
percent_increase = 0.1
num_policies = 20
es_path = "pickles/pdis_1.pkl"
gamma = 0.95
delta = 0.01 #1 - delta, confidence
random_seed = 88885555 #NOTE, this seed is for numpy operations. Since we load in CMA-ES from file its seed and state are embedded in the save and constant
sub_dir = "pdis_1\\"
title_offset = 41 # 1, 11, 21, so on

# seeds 508 (is_1.pkl), 1337 (is_0.pkl), 88885555 (pdis_1.pkl), 877496444 (pdis_0.pkl), 3125832 (pdis_2.pkl)
np.random.seed(random_seed) #this is to recreate the same policies

# %% [markdown]
# ***Setup Environment***

# %%
num_states = 18
if(USE_GRIDWORLD):
    print("Using Gridworld")
    num_states = 23
num_actions = 4

# %%
path = "data\data.csv"
if(USE_GRIDWORLD):
    path = "data\gridworld_data.csv"

histories = GetHistories(path, gamma)
# random.shuffle(histories)
# Out:
# line 0
# line 1000000
# line 2000000
# line 3000000
# line 4000000
# line 5000000
# line 6000000
# line 7000000
# line 8000000
# line 9000000
# line 10000000
# line 11000000
# line 12000000
# line 13000000
# line 14000000
# line 15000000
# line 16000000
# line 17000000
# line 18000000
# line 19000000
# line 20000000
# line 21000000
# line 22000000
# line 23000000
# line 24000000
# line 25000000
# line 26000000
# line 27000000
# line 28000000
# line 29000000
# line 30000000
# line 31000000
# line 32000000
# line 33000000
# line 34000000
# line 35000000
# line 36000000
# line 37000000
# line 38000000
# line 39000000
# line 40000000
# line 41000000
# line 42000000
# line 43000000
# line 44000000
# line 45000000
# line 46000000
# line 47000000
# line 48000000
# line 49000000
# line 50000000
# line 51000000
# line 52000000
# line 53000000
# line 54000000
# line 55000000
# line 56000000
# line 57000000
# line 58000000
# line 59000000
# line 60000000
# line 61000000
# line 62000000

# %%
train, test = SplitData(histories)
# Out:
# 800000
# 200000

# %%
avg_exploratory_J = GetAverageReturn(histories)
# Out:
# Average Baseline Return : 1.172600237817154

# %%
target_performance = GetTargetPerformance(USE_GRIDWORLD, avg_exploratory_J, percent_increase)
# Out:
# Target Performance : 1.556907

# %%
exploration_policy = GetPolicy(train, num_states, num_actions, 1000)
print(exploration_policy)
# Out:
# [[0.25  0.25  0.25  0.25 ]
#  [0.25  0.25  0.25  0.25 ]
#  [0.25  0.25  0.25  0.25 ]
#  [0.25  0.25  0.25  0.25 ]
#  [0.25  0.25  0.25  0.25 ]
#  [0.25  0.25  0.25  0.25 ]
#  [0.25  0.25  0.25  0.25 ]
#  [0.25  0.25  0.25  0.25 ]
#  [0.25  0.25  0.25  0.25 ]
#  [0.25  0.25  0.25  0.25 ]
#  [0.25  0.25  0.25  0.25 ]
#  [0.25  0.25  0.25  0.25 ]
#  [0.25  0.25  0.25  0.25 ]
#  [0.25  0.25  0.25  0.25 ]
#  [0.25  0.25  0.25  0.25 ]
#  [0.    0.    0.    0.   ]
#  [0.25  0.25  0.25  0.25 ]
#  [0.375 0.375 0.125 0.125]]

# %%
ISFunc = ImportanceSampling
OtherFunc = PDImportanceSampling
if(USE_PDIS):
    ISFunc = PDImportanceSampling
    OtherFunc = ImportanceSampling

# %%
es = pickle.load(open(es_path, "rb"))
print("ES_Convergence : " + str(sum(es.mean**2)))
print(es.opts["seed"])
# Out:
# ES_Convergence : 229.87978034906064
# 493998

# %%
def policy_softmax(policy):
    numerators = np.exp(policy)
    return (numerators.T / np.sum(numerators, axis=1)).T

# %%
avg_returns = 0
new_policy = None
theoretical_fails = 0
actual_fails = 0
i = 0
while i < num_policies:
    passed_theoretical = False
    try:
        print("~x~~x~~~x~~~~~x~~~~~x~~~x~~~~~x~~~~x~~")
        print(i)
        solution = es.ask(1)[0].reshape(num_states, num_actions)
        solution[15,:] = 1
        new_policy = policy_softmax(solution)
        ConfirmBounds(False, target_performance, train, test, exploration_policy, gamma, new_policy, ISFunc, delta)
        if (USE_BOTH_PDIS_AND_IS):
            ConfirmBounds(False, target_performance, train, test, exploration_policy, gamma, new_policy, OtherFunc, delta)
        passed_theoretical = True
        #policy passes theoretic check

        actual_J = -1
        if(USE_GRIDWORLD):
            actual_J = GetGridworldReturn(new_policy, gamma, 100000)
        else:
            actual_J = GetMockworldReturn(new_policy, gamma, 100000)

        print("TEST RUN " + str(actual_J))
        print(actual_J > target_performance)
#         ConfirmBounds(True, actual_J, train, test, exploration_policy, gamma, new_policy, ISFunc, delta)
#         if (USE_BOTH_PDIS_AND_IS):
#             ConfirmBounds(True, actual_J, train, test, exploration_policy, gamma, new_policy, OtherFunc, delta)
        #policy passes actual check
        path = "text_policies\\" + sub_dir + "policy" + str(i + title_offset) + ".txt"
        WriteSolutionToTxt(path, solution)
        loaded_solution = LoadSolutionFromTxt(path, num_states, num_actions)
        assert np.sum(loaded_solution - solution) == 0
        
        avg_returns += actual_J
        i += 1
    except:
        print("___F A I L___")
        if(passed_theoretical):
            actual_fails += 1
        else:
            theoretical_fails += 1

avg_returns /= num_policies
print("Number of Actual Fails : " + str(actual_fails))
print("Number of Theoretical Fails : " + str(theoretical_fails))
print("Average Return : " + str(avg_returns))
print("Target : " + str(target_performance))
print("Confidence : " + str(delta))
# Out:
# ~x~~x~~~x~~~~~x~~~~~x~~~x~~~~~x~~~~x~~
# 0
# Value: 1.556907
# Predicted Baseline: 1.8919533474076085
# Safety Baseline: 4.1721307965321195
# ---distance of return from lower bounds ---
# Looseness Of Prediction : 0.3350463474076084
# Looseness Of Safety : 2.6152237965321197
# -------------------------------------------
# Value: 1.556907
# Predicted Baseline: 1.116224505235679
# Safety Baseline: 3.764748562548504
# ---distance of return from lower bounds ---
# Looseness Of Prediction : -0.4406824947643211
# Looseness Of Safety : 2.207841562548504
# ___F A I L___
# ~x~~x~~~x~~~~~x~~~~~x~~~x~~~~~x~~~~x~~
# 0
# Value: 1.556907
# Predicted Baseline: 3.834380503346094
# Safety Baseline: 6.364045379521214
# ---distance of return from lower bounds ---
# Looseness Of Prediction : 2.277473503346094
# Looseness Of Safety : 4.807138379521215
# -------------------------------------------
# Value: 1.556907
# Predicted Baseline: 3.296939203993367
# Safety Baseline: 6.206393981267752
# ---distance of return from lower bounds ---
# Looseness Of Prediction : 1.740032203993367
# Looseness Of Safety : 4.649486981267752
# -------------------------------------------
# TEST RUN 7.2328995200325545
# True
# ~x~~x~~~x~~~~~x~~~~~x~~~x~~~~~x~~~~x~~
# 1
# Value: 1.556907
# Predicted Baseline: 4.122796139958063
# Safety Baseline: 5.568451311910696
# ---distance of return from lower bounds ---
# Looseness Of Prediction : 2.5658891399580632
# Looseness Of Safety : 4.011544311910696
# -------------------------------------------
# Value: 1.556907
# Predicted Baseline: 3.6587291747922186
# Safety Baseline: 5.333399710418339
# ---distance of return from lower bounds ---
# Looseness Of Prediction : 2.1018221747922183
# Looseness Of Safety : 3.7764927104183394
# -------------------------------------------
# TEST RUN 6.907422481545056
# True
# ~x~~x~~~x~~~~~x~~~~~x~~~x~~~~~x~~~~x~~
# 2
# Value: 1.556907
# Predicted Baseline: 2.4020473718571944
# Safety Baseline: 6.197986064316699
# ---distance of return from lower bounds ---
# Looseness Of Prediction : 0.8451403718571944
# Looseness Of Safety : 4.641079064316699
# -------------------------------------------
# Value: 1.556907
# Predicted Baseline: 1.6599990873908235
# Safety Baseline: 6.008439015360225
# ---distance of return from lower bounds ---
# Looseness Of Prediction : 0.10309208739082343
# Looseness Of Safety : 4.451532015360225
# -------------------------------------------
# TEST RUN 7.426123036455603
# True
# ~x~~x~~~x~~~~~x~~~~~x~~~x~~~~~x~~~~x~~
# 3
# Value: 1.556907
# Predicted Baseline: 2.6320194014876934
# Safety Baseline: 5.745645539550423
# ---distance of return from lower bounds ---
# Looseness Of Prediction : 1.0751124014876934
# Looseness Of Safety : 4.188738539550423
# -------------------------------------------
# Value: 1.556907
# Predicted Baseline: 1.8911306578172846
# Safety Baseline: 5.464703057431945
# ---distance of return from lower bounds ---
# Looseness Of Prediction : 0.3342236578172846
# Looseness Of Safety : 3.907796057431945
# -------------------------------------------
# TEST RUN 7.3426099744615225
# True
# ~x~~x~~~x~~~~~x~~~~~x~~~x~~~~~x~~~~x~~
# 4
# Value: 1.556907
# Predicted Baseline: 4.268571212479714
# Safety Baseline: 6.39111065082233
# ---distance of return from lower bounds ---
# Looseness Of Prediction : 2.7116642124797146
# Looseness Of Safety : 4.83420365082233
# -------------------------------------------
# Value: 1.556907
# Predicted Baseline: 3.8015679166226573
# Safety Baseline: 6.260623190717865
# ---distance of return from lower bounds ---
# Looseness Of Prediction : 2.2446609166226574
# Looseness Of Safety : 4.7037161907178655
# -------------------------------------------
# TEST RUN 7.216680253439082
# True
# ~x~~x~~~x~~~~~x~~~~~x~~~x~~~~~x~~~~x~~
# 5
# Value: 1.556907
# Predicted Baseline: 4.201659695271859
# Safety Baseline: 6.911719704892361
# ---distance of return from lower bounds ---
# Looseness Of Prediction : 2.644752695271859
# Looseness Of Safety : 5.354812704892361
# -------------------------------------------
# Value: 1.556907
# Predicted Baseline: 3.7465487719558412
# Safety Baseline: 6.862471974290553
# ---distance of return from lower bounds ---
# Looseness Of Prediction : 2.1896417719558414
# Looseness Of Safety : 5.3055649742905535
# -------------------------------------------
# TEST RUN 7.123674961115084
# True
# ~x~~x~~~x~~~~~x~~~~~x~~~x~~~~~x~~~~x~~
# 6
# Value: 1.556907
# Predicted Baseline: 3.7734693113599276
# Safety Baseline: 6.269037215491366
# ---distance of return from lower bounds ---
# Looseness Of Prediction : 2.2165623113599278
# Looseness Of Safety : 4.712130215491366
# -------------------------------------------
# Value: 1.556907
# Predicted Baseline: 3.2480962998319063
# Safety Baseline: 6.100173211506537
# ---distance of return from lower bounds ---
# Looseness Of Prediction : 1.6911892998319062
# Looseness Of Safety : 4.543266211506537
# -------------------------------------------
# TEST RUN 7.279644407793072
# True
# ~x~~x~~~x~~~~~x~~~~~x~~~x~~~~~x~~~~x~~
# 7
# Value: 1.556907
# Predicted Baseline: -0.26415047941436676
# Safety Baseline: 3.419588813637398
# ---distance of return from lower bounds ---
# Looseness Of Prediction : -1.8210574794143668
# Looseness Of Safety : 1.862681813637398
# ___F A I L___
# ~x~~x~~~x~~~~~x~~~~~x~~~x~~~~~x~~~~x~~
# 7
# Value: 1.556907
# Predicted Baseline: 3.5677431245348807
# Safety Baseline: 6.024497679006162
# ---distance of return from lower bounds ---
# Looseness Of Prediction : 2.0108361245348805
# Looseness Of Safety : 4.467590679006162
# -------------------------------------------
# Value: 1.556907
# Predicted Baseline: 3.009142979440648
# Safety Baseline: 5.8283158729989655
# ---distance of return from lower bounds ---
# Looseness Of Prediction : 1.4522359794406479
# Looseness Of Safety : 4.271408872998966
# -------------------------------------------
# TEST RUN 7.2052074422045
# True
# ~x~~x~~~x~~~~~x~~~~~x~~~x~~~~~x~~~~x~~
# 8
# Value: 1.556907
# Predicted Baseline: 3.3738642834249335
# Safety Baseline: 5.920271017319225
# ---distance of return from lower bounds ---
# Looseness Of Prediction : 1.8169572834249335
# Looseness Of Safety : 4.363364017319225
# -------------------------------------------
# Value: 1.556907
# Predicted Baseline: 2.8347331626970025
# Safety Baseline: 5.739130370387059
# ---distance of return from lower bounds ---
# Looseness Of Prediction : 1.2778261626970024
# Looseness Of Safety : 4.182223370387059
# -------------------------------------------
# TEST RUN 7.0210110664381835
# True
# ~x~~x~~~x~~~~~x~~~~~x~~~x~~~~~x~~~~x~~
# 9
# Value: 1.556907
# Predicted Baseline: 3.2453864725166452
# Safety Baseline: 6.228885011303543
# ---distance of return from lower bounds ---
# Looseness Of Prediction : 1.6884794725166452
# Looseness Of Safety : 4.671978011303543
# -------------------------------------------
# Value: 1.556907
# Predicted Baseline: 2.6696380086752685
# Safety Baseline: 6.0893607930605835
# ---distance of return from lower bounds ---
# Looseness Of Prediction : 1.1127310086752684
# Looseness Of Safety : 4.532453793060584
# -------------------------------------------
# TEST RUN 7.104258195786865
# True
# ~x~~x~~~x~~~~~x~~~~~x~~~x~~~~~x~~~~x~~
# 10
# Value: 1.556907
# Predicted Baseline: 0.6362608509813841
# Safety Baseline: 4.012697679468542
# ---distance of return from lower bounds ---
# Looseness Of Prediction : -0.920646149018616
# Looseness Of Safety : 2.4557906794685422
# ___F A I L___
# ~x~~x~~~x~~~~~x~~~~~x~~~x~~~~~x~~~~x~~
# 10
# Value: 1.556907
# Predicted Baseline: 2.9282549838392904
# Safety Baseline: 5.139553838692503
# ---distance of return from lower bounds ---
# Looseness Of Prediction : 1.3713479838392904
# Looseness Of Safety : 3.5826468386925034
# -------------------------------------------
# Value: 1.556907
# Predicted Baseline: 2.2756389707967175
# Safety Baseline: 4.831098321664349
# ---distance of return from lower bounds ---
# Looseness Of Prediction : 0.7187319707967175
# Looseness Of Safety : 3.2741913216643495
# -------------------------------------------
# TEST RUN 6.710513883707567
# True
# ~x~~x~~~x~~~~~x~~~~~x~~~x~~~~~x~~~~x~~
# 11
# Value: 1.556907
# Predicted Baseline: 3.0397515418265018
# Safety Baseline: 5.72321530206143
# ---distance of return from lower bounds ---
# Looseness Of Prediction : 1.4828445418265017
# Looseness Of Safety : 4.16630830206143
# -------------------------------------------
# Value: 1.556907
# Predicted Baseline: 2.407072963697993
# Safety Baseline: 5.490226471069683
# ---distance of return from lower bounds ---
# Looseness Of Prediction : 0.8501659636979928
# Looseness Of Safety : 3.933319471069683
# -------------------------------------------
# TEST RUN 7.190403362110569
# True
# ~x~~x~~~x~~~~~x~~~~~x~~~x~~~~~x~~~~x~~
# 12
# Value: 1.556907
# Predicted Baseline: 3.534854382595019
# Safety Baseline: 5.151316941511169
# ---distance of return from lower bounds ---
# Looseness Of Prediction : 1.977947382595019
# Looseness Of Safety : 3.594409941511169
# -------------------------------------------
# Value: 1.556907
# Predicted Baseline: 2.9779808176690823
# Safety Baseline: 4.819527500463029
# ---distance of return from lower bounds ---
# Looseness Of Prediction : 1.4210738176690823
# Looseness Of Safety : 3.2626205004630293
# -------------------------------------------
# TEST RUN 7.250846438317031
# True
# ~x~~x~~~x~~~~~x~~~~~x~~~x~~~~~x~~~~x~~
# 13
# Value: 1.556907
# Predicted Baseline: 3.9151576685246425
# Safety Baseline: 6.144278643213632
# ---distance of return from lower bounds ---
# Looseness Of Prediction : 2.3582506685246427
# Looseness Of Safety : 4.587371643213632
# -------------------------------------------
# Value: 1.556907
# Predicted Baseline: 3.432666366528239
# Safety Baseline: 5.985694880270042
# ---distance of return from lower bounds ---
# Looseness Of Prediction : 1.875759366528239
# Looseness Of Safety : 4.428787880270042
# -------------------------------------------
# TEST RUN 7.042853758256912
# True
# ~x~~x~~~x~~~~~x~~~~~x~~~x~~~~~x~~~~x~~
# 14
# Value: 1.556907
# Predicted Baseline: 3.317106801650083
# Safety Baseline: 5.090501893502986
# ---distance of return from lower bounds ---
# Looseness Of Prediction : 1.760199801650083
# Looseness Of Safety : 3.533594893502986
# -------------------------------------------
# Value: 1.556907
# Predicted Baseline: 2.7302924149153283
# Safety Baseline: 4.772454776130022
# ---distance of return from lower bounds ---
# Looseness Of Prediction : 1.1733854149153282
# Looseness Of Safety : 3.2155477761300224
# -------------------------------------------
# TEST RUN 7.089151942206978
# True
# ~x~~x~~~x~~~~~x~~~~~x~~~x~~~~~x~~~~x~~
# 15
# Value: 1.556907
# Predicted Baseline: 3.767556750877656
# Safety Baseline: 6.354906816476168
# ---distance of return from lower bounds ---
# Looseness Of Prediction : 2.210649750877656
# Looseness Of Safety : 4.797999816476168
# -------------------------------------------
# Value: 1.556907
# Predicted Baseline: 3.239146901812618
# Safety Baseline: 6.227969959201467
# ---distance of return from lower bounds ---
# Looseness Of Prediction : 1.6822399018126182
# Looseness Of Safety : 4.671062959201467
# -------------------------------------------
# TEST RUN 6.987199653558946
# True
# ~x~~x~~~x~~~~~x~~~~~x~~~x~~~~~x~~~~x~~
# 16
# Value: 1.556907
# Predicted Baseline: -2.6732971398905043
# Safety Baseline: 3.4473756843647
# ---distance of return from lower bounds ---
# Looseness Of Prediction : -4.230204139890504
# Looseness Of Safety : 1.8904686843647
# ___F A I L___
# ~x~~x~~~x~~~~~x~~~~~x~~~x~~~~~x~~~~x~~
# 16
# Value: 1.556907
# Predicted Baseline: 4.094087951099409
# Safety Baseline: 7.085691690220068
# ---distance of return from lower bounds ---
# Looseness Of Prediction : 2.537180951099409
# Looseness Of Safety : 5.528784690220069
# -------------------------------------------
# Value: 1.556907
# Predicted Baseline: 3.5835061526931273
# Safety Baseline: 7.017535892472607
# ---distance of return from lower bounds ---
# Looseness Of Prediction : 2.0265991526931275
# Looseness Of Safety : 5.460628892472607
# -------------------------------------------
# TEST RUN 7.5324944203211395
# True
# ~x~~x~~~x~~~~~x~~~~~x~~~x~~~~~x~~~~x~~
# 17
# Value: 1.556907
# Predicted Baseline: 3.8044399272143297
# Safety Baseline: 6.418985531188685
# ---distance of return from lower bounds ---
# Looseness Of Prediction : 2.24753292721433
# Looseness Of Safety : 4.862078531188685
# -------------------------------------------
# Value: 1.556907
# Predicted Baseline: 3.311369303718148
# Safety Baseline: 6.310841509775054
# ---distance of return from lower bounds ---
# Looseness Of Prediction : 1.754462303718148
# Looseness Of Safety : 4.753934509775054
# -------------------------------------------
# TEST RUN 7.063398839257635
# True
# ~x~~x~~~x~~~~~x~~~~~x~~~x~~~~~x~~~~x~~
# 18

# %%
greed_policy = np.argmax(new_policy,axis=1)

if(USE_GRIDWORLD):
    print(np.insert(greed_policy, [12,16],[-1,-1]).reshape((5,5)))
else:
    print(greed_policy[-2:])
    print(greed_policy[:-2].reshape(4,4))
